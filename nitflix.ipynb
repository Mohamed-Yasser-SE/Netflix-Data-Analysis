# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\shiko\Desktop\projects\nitflix\netflix_titles.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data=df[['type','director','title','rating','release_year','country']].dropna().reset_index()
data
# Out:
#       index     type             director                          title  \
# 0         0    Movie      Kirsten Johnson           Dick Johnson Is Dead
# 1         7    Movie         Haile Gerima                        Sankofa
# 2         8  TV Show      Andy Devonshire  The Great British Baking Show
# 3         9    Movie       Theodore Melfi                   The Starling
# 4        12    Movie  Christian Schwochow                   Je Suis Karl
# ...     ...      ...                  ...                            ...
# 5745   8801    Movie      Majid Al Ansari                        Zinzana
# 5746   8802    Movie        David Fincher                         Zodiac
# 5747   8804    Movie      Ruben Fleischer                     Zombieland
# 5748   8805    Movie         Peter Hewitt                           Zoom
# 5749   8806    Movie          Mozez Singh                         Zubaan
#
#      rating  release_year                                            country
# ...

# %%
dup=data['title'].duplicated().sum()
print(f"sum of duplicates = {dup}")
# Out:
# sum of duplicates = 0

# %%
d=data['type'].value_counts()
plt.figure(figsize=(8,5))
plt.bar(d.index,d.values,color='black')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.title('Number of movies and TV shows released from 1942 to 2021')
for i,v in enumerate(d):
    plt.text(i,v,v,ha='center',va='bottom')
plt.show()

# %%
labels=(d.values/(5561+189)*100).round(1)
plt.pie(d,startangle=90,labels=labels,colors=['black','b'])
plt.legend(labels=d.index,loc='upper right')
plt.show()

# %%
d2=data['release_year'].value_counts()
d2
# Out:
# release_year
# 2017    736
# 2018    707
# 2016    640
# 2019    571
# 2020    488
#        ...
# 1961      1
# 1963      1
# 1959      1
# 1966      1
# 1947      1
# Name: count, Length: 73, dtype: int64

# %%
df2=pd.DataFrame({'year':d2.index,'values':d2.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='year',y='values',data=df2,palette='flare')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.xticks(rotation=90)
plt.title('Number of movies and TV shows each year')
plt.xlabel('YEAR')
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\1952031986.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='year',y='values',data=df2,palette='flare')

# %%
d3=data['director'].value_counts()
valuess=d3.loc[d3.values>6]
df3=pd.DataFrame({'Directors':valuess.index,'values':valuess.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='Directors',y='values',data=df3,palette='crest')
plt.title('Directors who directed more than 6 movies and TV shows')
plt.xlabel('Directors')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\2919734626.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Directors',y='values',data=df3,palette='crest')

# %%
d4=data.loc[data['type']=='Movie']
d42=d4['director'].value_counts()
valuess2=d42.loc[d42.values>6]
df4=pd.DataFrame({'Directors':valuess2.index,'values':valuess2.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='Directors',y='values',data=df4,palette='flare')
plt.title('Directors who directed more than 6 movies')
plt.xlabel('Directors')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\2040935244.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Directors',y='values',data=df4,palette='flare')

# %%
d5=data.loc[data['type']=='TV Show']
d52=d5['director'].value_counts()
valuess3=d52.loc[d52.values>1]
df5=pd.DataFrame({'Directors':valuess3.index,'values':valuess3.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='Directors',y='values',data=df5,palette='rocket')
plt.title('Directors who directed more than 1 TV shows')
plt.xlabel('Directors')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\4173318415.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Directors',y='values',data=df5,palette='rocket')

# %%
d6=data['country'].value_counts()
va=d6.loc[d6.values>6]
df6=pd.DataFrame({'country':va.index,'values':va.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='country',y='values',data=df6,palette='crest')
plt.title('The country that made more than 6 movies and TV shows')
plt.xlabel('The country')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\2791473444.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='country',y='values',data=df6,palette='crest')

# %%
d7=data.loc[data['type']=='Movie']
d72=d7['country'].value_counts()
va2=d72.loc[d72.values>6]
df7=pd.DataFrame({'country':va2.index,'values':va2.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='country',y='values',data=df7,palette='flare')
plt.title('The country that made more than 6 movies')
plt.xlabel('The country')
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\683498068.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='country',y='values',data=df7,palette='flare')

# %%
d8=data.loc[data['type']=='TV Show']
d82=d8['country'].value_counts()
va3=d82.loc[d82.values>1]
df8=pd.DataFrame({'country':va3.index,'values':va3.values})
plt.figure(figsize=(20,5))  
sns.barplot(x='country',y='values',data=df8,palette='rocket')
plt.title('The country that made more than 1 TV shows')
plt.xlabel('The country')
plt.xticks(rotation=90)
plt.grid(axis='y',color='b',alpha=0.5,linestyle=':')
plt.show()
# Out:
# C:\Users\shiko\AppData\Local\Temp\ipykernel_16004\677419287.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='country',y='values',data=df8,palette='rocket')
